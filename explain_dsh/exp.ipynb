# %%
import numpy as np  
import pandas as pd
import os 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score, recall_score, f1_score, classification_report

# %%
diabetes = pd.read_csv("diabetes.csv")

# %%
df = diabetes.copy()
df = df.dropna()
y = df["Outcome"]
X = df.drop(['Outcome'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.30, 
                                                    random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_params = {"max_depth": [2,5,8,10],
            "max_features": [2,5,8],
            "n_estimators": [10,500,1000],
            "min_samples_split": [2,5,10]}

# %%
rf_model = RandomForestClassifier()

rf_cv_model = GridSearchCV(rf_model, 
                           rf_params, 
                           cv = 10, 
                           n_jobs = -1, 
                           verbose = 2)

# %%
rf_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 5, 8, 10], 'max_features': [2, 5, 8],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 500, 1000]},
#              verbose=2)

# %%
print("En iyi parametreler: " + str(rf_cv_model.best_params_))
# Out:
# En iyi parametreler: {'max_depth': 8, 'max_features': 8, 'min_samples_split': 2, 'n_estimators': 1000}

# %%
rf_tuned = RandomForestClassifier(max_depth = 8, 
                                  max_features = 8, 
                                  min_samples_split = 2,
                                  n_estimators = 1000)

rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features=8, n_estimators=1000)

# %%
y_pred = rf_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7532467532467533

# %%
from shapash import SmartExplainer
from shapash import SmartExplainer
xpl = SmartExplainer(model = rf_tuned)

# %%
xpl.compile( x = X_train,

)

# %%
app = xpl.run_app(host='localhost')
# Out:
# INFO:root:Your Shapash application run on http://localhost:8050/
# Dash is running on http://localhost:8050/
# INFO:root:Use the method .kill() to down your app.
# INFO:shapash.webapp.smart_app:Dash is running on http://localhost:8050/
#  * Serving Flask app 'shapash.webapp.smart_app'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:8050
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:37] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:37] "GET /assets/material-icons.css?m=1678204110.3631325 HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:37] "GET /assets/style.css?m=1678204110.3715782 HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:37] "GET /assets/jquery.js?m=1678204110.360133 HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:37] "GET /assets/main.js?m=1678204110.361133 HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /_dash-layout HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /assets/shapash-fond-fonce.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /assets/settings.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "GET /assets/reload.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:38] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 204 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:39] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:40] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:40] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:40] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:41] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:41] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:41] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:41] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:41] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [11/Mar/2023 20:08:42] "POST /_dash-update-component HTTP/1.1" 200 -
